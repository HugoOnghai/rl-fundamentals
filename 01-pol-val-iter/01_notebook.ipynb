# %%
import sys
from pathlib import Path

path = str(Path('01-pol-val-iter').resolve())
if path not in sys.path:
    sys.path.insert(0, path)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from project4.mdp import build_transitions
from project4.maze import Maze

# %%
from project4.parameters import *
from pol_iter import *

env = Maze()
P = build_transitions(env)

_, _ = policy_iteration(NUM_STATES, P)
# Out:
# === Beginning Policy Iteration ===
# Policy Iteration stabilized after 8 iterations.
